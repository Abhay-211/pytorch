# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhay-211/pytorch/blob/main/cputogpu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

t=torch.arange(5)
print(t)
t.device
# Out:
# tensor([0, 1, 2, 3, 4])
# device(type='cpu')

# %%
import torch

device = torch.device("cuda")

tensor = torch.tensor([1,2,3]).to(device)

print(tensor.device)
# Out:
# cuda:0

# %%
is_available = torch.cuda.is_available()
print(is_available)
# Out:
# True

# %%
num_devices = torch.cuda.device_count()
print(num_devices)
# Out:
# 1

# %%
if is_available:
    gpu_name = torch.cuda.get_device_name(0)
    print(gpu_name)
# Out:
# Tesla T4

# %%
device=torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
cpu_tensor=torch.randn(3,3)
print(f"cpu tensor device:{cpu_tensor.device}")
# Out:
# cpu tensor device:cpu

# %%
if device.type=='cuda':
  gpu_tensor=cpu_tensor.to(device)
  print(f"GPU tensor device:{gpu_tensor.device}")
else:
  print("GPU not available")
# Out:
# GPU tensor device:cuda:0

# %%
import torch
import time

device = torch.device("cuda")

# Create large tensors on GPU
a = torch.randn(5000, 5000).to(device)
b = torch.randn(5000, 5000).to(device)

start = time.time()

c = torch.matmul(a, b)

torch.cuda.synchronize()  # wait for GPU to finish

end = time.time()

print(f"Time taken: {end-start:.4f} seconds")
print(c.device)
# Out:
# Time taken: 0.2141 seconds
# cuda:0

# %%
print(torch.cuda.memory_allocated()/1024**3, "GB used")
print(torch.cuda.memory_reserved()/1024**3, "GB reserved")
# Out:
# 0.2891855239868164 GB used
# 0.302734375 GB reserved

# %%
import numpy as np
# Assuming gpu_tensor exists and is on CUDA
if device.type == 'cuda':
    cpu_result_tensor = gpu_tensor.to('cpu') # or gpu_tensor.cpu()
    print(f"Moved back to CPU: {cpu_result_tensor.device}")

    # You can now convert it to a NumPy array
    numpy_array = cpu_result_tensor.numpy()
    print(f"Converted to NumPy array: {type(numpy_array)}")
else:
    print("GPU not used, no need to move back to CPU.")
# Out:
# Moved back to CPU: cpu
# Converted to NumPy array: <class 'numpy.ndarray'>

# %%
print(t)
# Out:
# tensor([0, 1, 2, 3, 4])
