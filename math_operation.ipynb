# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhay-211/pytorch/blob/main/math_operation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TENSOR
#
# *   ADD,SUBTRACT,DIVIDE,MULTIPLY,REMAINDERS,EXPONENT
#
# *   SHORTHAND AND LONGHAND
# REASSIGNMENT

# %%
import torch
import numpy as np

# %%
tensor_a =torch.tensor([1,2,3,4])
tensor_b =torch.tensor([5,6,7,8])

# %%
# addition
tensor_a + tensor_b
# Out:
# tensor([ 6,  8, 10, 12])

# %%
## addition Longhand
torch.add(tensor_a , tensor_b )
# Out:
# tensor([ 6,  8, 10, 12])

# %%
#subtract
tensor_b - tensor_a
# Out:
# tensor([4, 4, 4, 4])

# %%
#subb function
torch.sub(tensor_b , tensor_a)
# Out:
# tensor([4, 4, 4, 4])

# %%
#multiplication longhand
torch.mul(tensor_a , tensor_b)
# Out:
# tensor([ 5, 12, 21, 32])

# %%
#divison longhand
torch.div(tensor_b , tensor_a)
# Out:
# tensor([5.0000, 3.0000, 2.3333, 2.0000])

# %%
# remainder function
tensor_b % tensor_a
# Out:
# tensor([0, 0, 1, 0])

# %%
# remainder longhand
torch.remainder(tensor_b , tensor_a)
# Out:
# tensor([0, 0, 1, 0])

# %%
#tensor exponents
torch.pow(tensor_a,tensor_b)
# Out:
# tensor([    1,    64,  2187, 65536])

# %%
#another way for longhand
tensor_a.add(tensor_b)
# Out:
# tensor([ 6,  8, 10, 12])

# %%
tensor_a=tensor_a +tensor_b
tensor_a
# Out:
# tensor([11, 14, 17, 20])

# %%
tensor_a
# Out:
# tensor([11, 14, 17, 20])
